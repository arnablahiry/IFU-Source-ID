# %%
import numpy as np, sys
sys.path.insert(0, '.')
from flow_tracker import run_flow_tracker
cube = np.zeros((6,50,50), dtype='f4')
for ch in range(6): cube[ch,23:28,23:28] = 1.0
for ch in [1,2,3]: cube[ch,23:28,30:35] = 1.0
_, _, tracks, sources = run_flow_tracker(cube, list(range(6)),
    scales=3, k_sigma=1.0, use_scale=2, min_area=5,
    max_link_dist=20, max_split_dist=35, min_displacement=1)
print('tracks:', len(tracks), '  sources:', len(sources))
assert len(sources) == 1, 'split+rejoin must be 1 source'
print('PASS')
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# tracks: 2   sources: 1
# PASS

# %%
import matplotlib.pyplot as plt

plt.imshow(cube[0])
